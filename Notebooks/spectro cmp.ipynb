# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20.0,10.0)
import sys
sys.path.append('../')
import spectrocmp
import matplotlib.pyplot as plt
import numpy as np

# %%
cmp = spectrocmp.SpectroCausalMP('../../Data/speech_corpora/TIMIT_spectrograms')
# Out:
# Found  6293  files

# %%
cmp.thresh = 0.01
cmp.normed_thresh = 0.015
cmp.test_inference(300)
# Out:
# Signal-noise ratio:  0.0784931067289  dB

# %%
cmp.learn_rate = 0.001
cmp.train(1000)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950

# %%
cmp.show_dict()

# %%
cmp.save()

# %%
cmp.load(cmp.paramfile)

# %%
cmp.test_inference()
# Out:
# Signal-noise ratio:  8.04993465596  dB

# %%
cmp.progress_plot(10)

# %%
cmp.thresh = 0.01
cmp.normed_thresh = 0.025
cmp.train(1000)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
